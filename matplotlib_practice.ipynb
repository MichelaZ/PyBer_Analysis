# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm

x = np.linspace(0, 3 * np.pi, 500)
y = np.sin(x)
dydx = np.cos(0.5 * (x[:-1] + x[1:]))  # first derivative

# Create a set of line segments so that we can color them individually
# This creates the points as a N x 1 x 2 array so that we can stack points
# together easily to get the segments. The segments array for line collection
# needs to be (numlines) x (points per line) x 2 (for x and y)
points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

fig, axs = plt.subplots(2, 1, sharex=True, sharey=True)

# Create a continuous norm to map from data points to colors
norm = plt.Normalize(dydx.min(), dydx.max())
lc = LineCollection(segments, cmap='viridis', norm=norm)
# Set the values used for colormapping
lc.set_array(dydx)
lc.set_linewidth(2)
line = axs[0].add_collection(lc)
fig.colorbar(line, ax=axs[0])

# Use a boundary norm instead
cmap = ListedColormap(['r', 'g', 'b'])
norm = BoundaryNorm([-1, -0.5, 0.5, 1], cmap.N)
lc = LineCollection(segments, cmap=cmap, norm=norm)
lc.set_array(dydx)
lc.set_linewidth(2)
line = axs[1].add_collection(lc)
fig.colorbar(line, ax=axs[1])

axs[0].set_xlim(x.min(), x.max())
axs[0].set_ylim(-1.1, 1.1)
plt.show()

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics
import numpy as np

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create and format the plot/bubble
plt.scatter(x_axis, y_axis, marker='o', s = [i * 3 for i in y_axis], label="Chicago", c="purple")
#add labels
plt.xlabel("Date")
plt.ylabel("Fare($)")
#add title
plt.title("PyBer Fare by Month")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, s=[i* 5 for i in y_axis], marker='o',c="skyblue", alpha=.8, linewidths=2,  edgecolors="black", label="Boston")
#Decending y_axis
plt.gca().invert_yaxis()
#x-axis limit
plt.xlim(0,50)
#add labels
plt.xlabel("Fare($)")
plt.ylabel("Months")
#add title
plt.title("PyBer Fare by Month")
plt.legend()

# %%
plt.pie(y_axis, labels=x_axis)

plt.show()

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')
plt.gca().invert_yaxis()
plt.show()

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, .2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis,
    explode=explode_values,
    startangle=265,
    shadow='True',
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')
plt.gca().invert_yaxis()
plt.show()

# %%
#Create and format the plot/line
plt.plot(x_axis, y_axis, label='Boston', marker="d", c="skyblue", linewidth=2)
stdev = statistics.stdev(y_axis)
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3, color="grey")
#add labels
plt.xlabel("Date")
plt.ylabel("Fare($)")
#add title/legend/grid
plt.title("PyBer Fare by Month")
plt.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
ax.plot(x_axis,y_axis)

# %%
# Create and format the plot/line
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3, color="orange", label='Boston')
#add labels
plt.xlabel("Date")
plt.ylabel("Fare($)")
#add title
plt.title("PyBer Fare by Month")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3, color="darkseagreen", label="New York")
plt.show()

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
